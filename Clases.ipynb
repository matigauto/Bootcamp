# %%
solucion1 = "Hola"
solucion2 = "Mati"
print (f"{solucion1} soy {solucion2}")
# Out:
# Hola soy Mati
# 1234

# %%
print ("hello world")
# Out:
# hello world

# %%
edad = 17
nombre = "mati"
ciudad = "lambare"

print (f"soy {nombre} tengo {edad} y soy de {ciudad}")
# Out:
# soy mati tengo 17 y soy de lambare

# %%
manzanas_total = 25
cantidad_naranjas = 30

cantidadfrutas = manzanas_total + cantidad_naranjas

frutas_vendidas = 15
frutas_restantes = cantidadfrutas - frutas_vendidas
cantidad_frutas = frutas_restantes

print (f'las frutas que quedan son {frutas_restantes} y se vendieron varias mas u menos {frutas_vendidas}')
# Out:
# las frutas que quedan son 40 y se vendieron varias mas u menos 15

# %%
nombre = "Lucas" 
apellido = "Fernandez"


print (f"Hola mi nombre es {nombre} {apellido}. Mucho gusto!")
# Out:
# Hola mi nombre es Lucas Fernandez. Mucho gusto!

# %%
Caramelos = int(input("Cuantos caramelos son"))
Ninos = int(input("Cuantos niños son"))
Caramelos_reciben = Caramelos // Ninos
Caramelos_sobran = Caramelos % Ninos

print(f"Tienes que entregar, {Caramelos_reciben} a cada niño. Te sobrarian, {Caramelos_sobran},  Caramelos")
# Out:
# Tienes que entregar, 2 a cada niño. Te sobrarian, 0,  Caramelos

# %%
def contestador():  
    nombre = input("ingresar tu nombre")
    apellido = input("ingresar apellido")
    print(f'hola {nombre} {apellido} no esta disponible')

def aclaracion():  
    nombre = input("ingresar tu nombre")
    print(f'vuelve a contactar mas tarde a {nombre}')

def sugerencia():  
    Proba = 'Contactarlo por medio de su madre'podria ser ideal
    print(Proba)



contestador()
aclaracion()
sugerencia()
# Out:
#   Cell In[56], line 11
#     Proba = 'Contactarlo por medio de su madre'podria ser ideal
#                                                ^
# SyntaxError: invalid syntax

# %%
pedido_auto = input('Que modelo le interesa')
version_auto = input('en que version le interesa. Simple, Equipada, Full')
def pedido(modelo, version):
    print(f'preparando tu {modelo}, sera entregado en las proximas horas')
    print(f'su {modelo} estara listo en cuanto lleguen las versiones {version}')


pedido(pedido_auto, version_auto)
# Out:
# preparando tu Tacoma, sera entregado en las proximas horas
# su Tacoma estara listo en cuanto lleguen las versiones full

# %%
impuesto = 1.1

def calculartotal():
    precio = int(input('ingrese el precio'))
    Total = precio * impuesto
    print(f'el total es {Total}')

calculartotal()
# Out:
# el total es 7700.000000000001
