# %%
edad = int(input())
if edad < 8:
    print('Acceso denegado - Bebe kau no se permite')

elif edad >= 18:
    print('acceso negado, anda al globo loco si queres')

if edad  <= 21:
    print('acceso permitido - sin el chupi 🙁')

elif edad >= 75:
    print('ya sos grande para andar boludeando')

else:
    print('Disfruta del Asuncionico 🍺 (cuidate de la resaca 🤢)')

# %%
temperatura_usuario = float(input("Que temperatura esta tu motor"))
print(f'La temperatura ingresada es {temperatura_usuario}')
if temperatura_usuario >= -10 and temperatura_usuario <= 13: 
    print("Ro'y koko")
elif temperatura_usuario >= 14 and temperatura_usuario <= 23:
    print("Refresca'i")
elif temperatura_usuario >= 24 and temperatura_usuario <= 28:
    print("Oikoite")
elif temperatura_usuario >= 29 and temperatura_usuario <= 45:
    print("Hakurooooo")
else:
    print("Ñamano mba'e!")

# %%
numero_a_adivinar = 30
numero = 0

while numero != numero_a_adivinar:
    numero = int(input('Ingrese su fantastica contraseña'))
    print(numero)

print('Acceso concedido')

# %%
Contraseña = 'Amolaraptor2431+'

while True:
    contra_secreta = (input('ingresar numero'))
    if contra_secreta == Contraseña:
        print('La Contraseña es correcta, Bienvenido Batman')
        break
    
    else:
     print('La contraseña no es correcta. Autodestruccion activada')

# %%
nombre_usuario = input('Ingrese su nombre de usuario')
contrasena_usuario = input('Ingrese su contrasena')
nombre_almacenado = nombre_usuario
contrasena_almacenado = contrasena_usuario

while True:

  if nombre_almacenado == input('ingrese su usuario para iniciar sesion') and contrasena_almacenado == input('ingrese su contrasena para iniciar sesion'):
   print('contrasena correcta')
   print("Que grande capo")

   break 
  else:
    print('contrasena incorrecta')

# %%
Pokemones = ['pikachu','squirtle', 'charizard', 'portygot']
Pokemones[2] = 'charmander'
Pokemones.append(4) = 'Mewtwo'
Pokemones.remove[3]

print(Pokemones)

# %%
for i in range(10):
    print(i * 2)

# %%
lista_marcas = ['yamaha', 'colgate', 'rolex', 'coca-cola']
for elemento in lista_marcas:
    num_letras = len(elemento)
    if num_letras >= 6:
        print (elemento)
# Out:
# yamaha
# colgate
# coca-cola

# %%
palabras_usuario = input()
for carachter in palabras_usuario:
    if carachter == 'o'or 'O':
            print('esta palabra tiene o en la palabra')
# Out:
# esta palabra tiene o en la palabra
# esta palabra tiene o en la palabra
# esta palabra tiene o en la palabra
# esta palabra tiene o en la palabra
